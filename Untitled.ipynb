# %% [markdown]
# ## this notebook loads the profile produced by the profile notebook and display them as a contour 2D plot

# %%
import numpy as np
import os
import pandas as pd

# %% [markdown]
# ### load profile

# %%
profile_file = "/Volumes/JeanHardDrive/HFIR/CG1D/IPTS-25696-Guang/IPTS-25696-Guang_profile_1.txt"
assert os.path.exists(profile_file)

# %%
pd_data = pd.read_csv(profile_file, comment="#")

# %%
pd_data
# Out:
#      88   0.2023669   0.20025818   0.20537221   0.20474117   0.20249781  \
# 0    89    0.202421     0.199675     0.203989     0.203784     0.201259
# 1    90    0.203578     0.200893     0.203271     0.204148     0.200132
# 2    91    0.204359     0.199200     0.202118     0.202842     0.199892
# 3    92    0.203409     0.198198     0.201656     0.202237     0.198920
# 4    93    0.201328     0.198615     0.201538     0.199945     0.198867
# ..  ...         ...          ...          ...          ...          ...
# 56  145    0.199445     0.198449     0.198032     0.198378     0.199346
# 57  146    0.200726     0.199013     0.198347     0.200123     0.200021
# 58  147    0.202658     0.199474     0.198608     0.202109     0.201628
# 59  148    0.206248     0.202104     0.199702     0.202327     0.201790
# 60  149    0.208227     0.202948     0.201352     0.203424     0.203829
#
#      0.19930597   0.20068935   0.200887   0.20426139  ...   0.20165284  \
# ...
